# %%
import random
import pandas as pd
pd.options.display.max_columns = 0

import matplotlib.pyplot as plt

# %matplotlib inline

# %config InlineBackend.figure_format = "retina"

# %%
import os

parts_dir = "../data/1-feature-engineering"

parts_names = os.listdir(parts_dir)
parts_names = filter(lambda x: not x.startswith("."), parts_names)
parts_paths = sorted(map(lambda part_name: parts_dir + "/" + part_name, parts_names))

parts_paths[:5]
# Out:
# ['../data/1-feature-engineering/new.000.csv',
#  '../data/1-feature-engineering/new.001.csv',
#  '../data/1-feature-engineering/new.002.csv',
#  '../data/1-feature-engineering/new.003.csv',
#  '../data/1-feature-engineering/new.004.csv']

# %%
# %%time

parts_dfs = tuple(map(pd.read_csv, parts_paths))

with pd.option_context("display.max_rows", 6): display(random.choice(parts_dfs))
# Out:
#        target  feature_1_1  feature_1_2  feature_1_3  ...  MODE(transactions.DAY(purchase_date))  MODE(transactions.YEAR(purchase_date))  MODE(transactions.MONTH(purchase_date))  MODE(transactions.WEEKDAY(purchase_date))
# 0    0.847922            0            0            0  ...                                      6                                    2017                                        7                                          3
# 1   -0.905887            0            0            0  ...                                     23                                    2017                                       12                                          5
# 2    0.573943            0            0            1  ...                                      2                                    2017                                        1                                          2
# ..        ...          ...          ...          ...  ...                                    ...                                     ...                                      ...                                        ...
# 807  2.407669            0            0            0  ...                                     24                                    2018                                        1                                          2
# 808 -0.087174            0            1            0  ...                                     25                                    2017                                        8                                          6
# 809 -1.136245            0            0            1  ...                                     30                                    2017                                        3                                          3
#
# [810 rows x 89 columns]
# CPU times: user 4.34 s, sys: 300 ms, total: 4.64 s
# Wall time: 4.64 s

# %%
# %%time

feature_matrix = pd.concat(parts_dfs, ignore_index=True, sort=False)

with pd.option_context("display.max_rows", 6): display(feature_matrix)
# Out:
#           target  feature_1_1  feature_1_2  feature_1_3  ...  MODE(transactions.DAY(purchase_date))  MODE(transactions.YEAR(purchase_date))  MODE(transactions.MONTH(purchase_date))  MODE(transactions.WEEKDAY(purchase_date))
# 0       0.492829            0            0            0  ...                                     11                                    2018                                        3                                          6
# 1       2.322680            0            1            0  ...                                     10                                    2018                                        2                                          5
# 2       0.856304            0            0            0  ...                                      1                                    2018                                        3                                          1
# ...          ...          ...          ...          ...  ...                                    ...                                     ...                                      ...                                        ...
# 381900  1.289601            0            1            0  ...                                      4                                    2017                                        1                                          5
# 381901  0.346886            0            1            0  ...                                     27                                    2017                                        2                                          0
# 381902 -1.902830            0            0            1  ...                                     17                                    2018                                        1                                          0
#
# [381903 rows x 89 columns]
# CPU times: user 942 ms, sys: 60.1 ms, total: 1 s
# Wall time: 914 ms

# %%
customers = feature_matrix.drop("MODE(transactions.merchant_id)", axis=1).fillna(0)

customers_ord = customers[customers.target > -33].sample(2000)
customers_ano = customers[customers.target < -33].sample(2000)

# %%
# %%time

from sklearn.manifold import TSNE

X = pd.concat((customers_ano, customers_ord))
y = (X.target < -33).astype(int)
X = X.drop("target", axis=1)

X_t = TSNE(random_state=13).fit_transform(X)
# Out:
# CPU times: user 23.7 s, sys: 27.9 ms, total: 23.8 s
# Wall time: 21.7 s

# %%
X_t_ord = X_t[y == 0]
X_t_ano = X_t[y == 1]

plt.scatter(X_t_ord[:, 0], X_t_ord[:, 1], marker='o', color='g', linewidth='0.5', alpha=0.8, label='Ordinary')
plt.scatter(X_t_ano[:, 0], X_t_ano[:, 1], marker='o', color='r', linewidth='0.5', alpha=0.8, label='Anomaly')

plt.legend(loc='best')
plt.show()

# %%
from keras.layers import Input, Dense
import keras.regularizers as regularizers

## input layer 
input_layer = Input(shape=(X.shape[1],))

## encoding part
encoded = Dense(256, activation='tanh', activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoded = Dense(128, activation='relu')(encoded)

## decoding part
decoded = Dense(128, activation='tanh')(encoded)
decoded = Dense(256, activation='tanh')(decoded)

## output layer
output_layer = Dense(X.shape[1], activation='relu')(decoded)

# %%
from keras.models import Model

autoencoder = Model(input_layer, output_layer)
autoencoder.compile(optimizer="adadelta", loss="mse")

# %%
from sklearn.preprocessing import MinMaxScaler

X_scaled = MinMaxScaler().fit_transform(X.values)
X_scaled_ord = X_scaled[y == 0]
X_scaled_ano = X_scaled[y == 1]

# %%
autoencoder.fit(X_scaled_ord, X_scaled_ord, 
                batch_size=64, epochs=35,
                shuffle=True,
                validation_split=0.20);
# Out:
# Train on 1600 samples, validate on 400 samples
# Epoch 1/35
# 1600/1600 [==============================] - 1s 513us/step - loss: 0.3314 - val_loss: 0.2461
# Epoch 2/35
# 1600/1600 [==============================] - 0s 89us/step - loss: 0.2294 - val_loss: 0.2085
# Epoch 3/35
# 1600/1600 [==============================] - 0s 67us/step - loss: 0.1973 - val_loss: 0.1821
# Epoch 4/35
# 1600/1600 [==============================] - 0s 90us/step - loss: 0.1734 - val_loss: 0.1628
# Epoch 5/35
# 1600/1600 [==============================] - 0s 72us/step - loss: 0.1575 - val_loss: 0.1501
# Epoch 6/35
# 1600/1600 [==============================] - 0s 67us/step - loss: 0.1456 - val_loss: 0.1394
# Epoch 7/35
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.1370 - val_loss: 0.1318
# Epoch 8/35
# 1600/1600 [==============================] - 0s 67us/step - loss: 0.1282 - val_loss: 0.1227
# Epoch 9/35
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.1195 - val_loss: 0.1151
# Epoch 10/35
# 1600/1600 [==============================] - 0s 69us/step - loss: 0.1165 - val_loss: 0.1053
# Epoch 11/35
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.1110 - val_loss: 0.1094
# Epoch 12/35
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.1051 - val_loss: 0.1069
# Epoch 13/35
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.1055 - val_loss: 0.0973
# Epoch 14/35
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.0989 - val_loss: 0.0942
# Epoch 15/35
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.0979 - val_loss: 0.0995
# Epoch 16/35
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.0949 - val_loss: 0.0943
# Epoch 17/35
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.0908 - val_loss: 0.0916
# Epoch 18/35
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.0919 - val_loss: 0.0869
# Epoch 19/35
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.0867 - val_loss: 0.0840
# Epoch 20/35
# 1600/1600 [==============================] - 0s 71us/step - loss: 0.0845 - val_loss: 0.0879
# Epoch 21/35
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.0855 - val_loss: 0.0814
# Epoch 22/35
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.0793 - val_loss: 0.0760
# Epoch 23/35
# 1600/1600 [==============================] - 0s 68us/step - loss: 0.0802 - val_loss: 0.0765
# Epoch 24/35
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.0790 - val_loss: 0.0801
# Epoch 25/35
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.0778 - val_loss: 0.0812
# Epoch 26/35
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.0756 - val_loss: 0.0753
# Epoch 27/35
# 1600/1600 [==============================] - 0s 51us/step - loss: 0.0748 - val_loss: 0.0789
# Epoch 28/35
# 1600/1600 [==============================] - 0s 54us/step - loss: 0.0739 - val_loss: 0.0708
# Epoch 29/35
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.0724 - val_loss: 0.0743
# Epoch 30/35
# 1600/1600 [==============================] - 0s 63us/step - loss: 0.0725 - val_loss: 0.0721
# Epoch 31/35
# 1600/1600 [==============================] - 0s 63us/step - loss: 0.0707 - val_loss: 0.0705
# Epoch 32/35
# 1600/1600 [==============================] - 0s 63us/step - loss: 0.0699 - val_loss: 0.0701
# Epoch 33/35
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.0682 - val_loss: 0.0684
# Epoch 34/35
# 1600/1600 [==============================] - 0s 51us/step - loss: 0.0685 - val_loss: 0.0690
# Epoch 35/35
# 1600/1600 [==============================] - 0s 59us/step - loss: 0.0672 - val_loss: 0.0709

# %%
from keras.models import Sequential

hidden_representation = Sequential()
hidden_representation.add(autoencoder.layers[0])
hidden_representation.add(autoencoder.layers[1])
hidden_representation.add(autoencoder.layers[2])

# %%
ord_hid_rep = hidden_representation.predict(X_scaled_ord)
ano_hid_rep = hidden_representation.predict(X_scaled_ano)

# %%
import numpy as np

rep_x = np.append(ord_hid_rep, ano_hid_rep, axis = 0)

# %%
# %%time

X_t = TSNE(random_state=13).fit_transform(rep_x)
# Out:
# CPU times: user 25.2 s, sys: 2.28 s, total: 27.5 s
# Wall time: 24.6 s

# %%
X_t_ord = X_t[y == 0]
X_t_ano = X_t[y == 1]

plt.scatter(X_t_ord[:, 0], X_t_ord[:, 1], marker='o', color='g', linewidth='0.5', alpha=0.8, label='Ordinary')
plt.scatter(X_t_ano[:, 0], X_t_ano[:, 1], marker='o', color='r', linewidth='0.5', alpha=0.8, label='Anomaly')

plt.legend(loc='best')
plt.show()
